# %% [markdown]
# ### Rotate for May 15 runs

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
path = "dataset/may15_run00_cam07/frame_340.png"
image = cv2.imread(path)

# Check if the image was successfully loaded
if image is None:
    print("Error: Unable to load image.")
else:
    # Rotate the image clockwise by 180 degrees
    rotated_image = cv2.rotate(image, cv2.ROTATE_180)

    # Display the original and rotated images using Matplotlib
    plt.figure(figsize=(10, 5))

    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # Rotated Image
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
    plt.title('Rotated Image')
    plt.axis('off')

    plt.show()

# %%
# Rotate all images in the directory by 180 degrees
import os

# Directory containing the images
directory = "dataset/may15_run00_cam07"

# Iterate over all the files in the directory
for filename in os.listdir(directory):
    # Check if the file is an image
    if filename.endswith(".png"):
        # Load the image
        image = cv2.imread(os.path.join(directory, filename))

        # Rotate the image clockwise by 180 degrees
        rotated_image = cv2.rotate(image, cv2.ROTATE_180)

        # Save the rotated image
        cv2.imwrite(os.path.join(directory, filename), rotated_image)

print("All images have been rotated by 180 degrees.")
# Out:
# All images have been rotated by 180 degrees.

# %% [markdown]
# ### Rotate for May 14 runs

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
path = "dataset/may14_run00/frame_80.png"
image = cv2.imread(path)

# Check if the image was successfully loaded
if image is None:
    print("Error: Unable to load image.")
else:
    # Rotate the image clockwise by 90 degrees
    rotated_image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

    # Display the original and rotated images using Matplotlib
    plt.figure(figsize=(10, 5))

    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # Rotated Image
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
    plt.title('Rotated Image')
    plt.axis('off')

    plt.show()

# %%
# Rotate all images in the directory by 90 degrees
import os

# Directory containing the images
directory = "dataset/may14_run00"

# Iterate over all the files in the directory
for filename in os.listdir(directory):
    # Check if the file is an image
    if filename.endswith(".png"):
        # Load the image
        image = cv2.imread(os.path.join(directory, filename))

        # Rotate the image clockwise by 90 degrees
        rotated_image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

        # Save the rotated image
        cv2.imwrite(os.path.join(directory, filename), rotated_image)

print("All images have been rotated by 90 degrees.")
# Out:
# All images have been rotated by 90 degrees.
